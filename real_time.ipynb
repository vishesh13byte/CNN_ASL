# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array
import imutils
import os
# Out:
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 import cv2
#       2 import numpy as np
# ----> 3 from tensorflow.keras.preprocessing.image import img_to_array
#       4 import imutils
#       5 import os
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\api\_v2\keras\__init__.py:8, in <module>
#       3 """Public API for tf.keras namespace.
#       4 """
#       6 import sys as _sys
# ----> 8 from keras import __version__
#       9 from keras.api._v2.keras import __internal__
#      10 from keras.api._v2.keras import activations
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\__init__.py:25, in <module>
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
# ...
